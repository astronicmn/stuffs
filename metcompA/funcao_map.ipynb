# %% [markdown]
# ## Função map

# %%
import math as mt
pi = mt.pi

# %%
x = list(range(0,10))

# %%
def f(x):
  return x**2

# %%
y = list(map(f, x))

# %%
y
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
