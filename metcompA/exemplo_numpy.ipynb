# %%
import numpy as np
from numpy import random
from time import time

# %%
random.rand()
# Out:
# 0.39037423466175614

# %%
x = np.random.rand(100)

# %%
def gera_random(N):
  for i in range(N):
    x = random.rand()

# %%
tic = time()
gera_random(100000)
tac = time()
tempo = tac - tic
tempo #cronometro que marca o tempo de execução da função
# Out:
# 0.04444718360900879

# %%
# %timeit np.random.rand(100000)
# Out:
# 1000 loops, best of 5: 890 µs per loop

# %%
# %timeit gera_random(100000)
# Out:
# 10 loops, best of 5: 32.8 ms per loop

# %%
v1 = np.array([1, 0, 0])
v2 = np.array([0, 1, 1])

# %%
v3 = 2 * v1 + 3 * v2

# %%
v3
# Out:
# array([2, 3, 3])

# %%
print(np.dot(v1, v2))
# Out:
# 0

# %%
print(np.cross(v1, v2))
# Out:
# [ 0 -1  1]
