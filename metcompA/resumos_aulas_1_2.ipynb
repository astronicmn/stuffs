# %% [markdown]
# # Comandos de entrada e saída

# %%
print('Olá!')
x=input('Entre com um número ')
#float(x)
# Out:
# Olá!
# Entre com um número 46

# %% [markdown]
# # Tipos de variáveis

# %%
4        #int
4.0      #float
'Olá'    #string
3.0 + 5J #complex
verdade_ou_mentira = 3 <= 5 #boolean

#Exemplo:
type(4.0)
# Out:
# float

# %%
#Exemplo 2:
print(verdade_ou_mentira)
# Out:
# True

# %% [markdown]
# # Nomes de variáveis

# %%
h_bar = 1.05457e-34 # ok!

# %%
2plus_forty = 42 # bad!
# Out:
#   File "<ipython-input-9-f9e4a183a2a5>", line 1
#     2plus_forty = 42 # bad!
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Indexando strings
# Lembrando que strings são listas de caracteres

# %%
p = "proton"
p[1] #índices começam no zero
# Out:
# 'r'

# %%
p[-1] #é possível indexar listas e strings de trás pra frente
# Out:
# 'n'

# %%
p[2:5] #slices não incluem o último elemento; no exemplo, o slice vai o elemento 2 ao 4 (5 é excluído)
# Out:
# 'oto'

# %% [markdown]
# # Concatenação de listas:

# %%
"kilo" + "meter"
# Out:
# 'kilometer'

# %%
10*'Newton' #multiplicação por inteiro também vale:
# Out:
# 'NewtonNewtonNewtonNewtonNewtonNewtonNewtonNewtonNewtonNewton'

# %% [markdown]
# # Elementos de Python - Containers

# %%
fib = [1, 1, 2, 3, 5, 8] #lista

# %%
fib.append(13) #adicionando um elemento ao final da lista
fib
# Out:
# [1, 1, 2, 3, 5, 8, 13]

# %%
fib.pop(5) #removendo um elemento
fib
# Out:
# [1, 1, 2, 3, 5, 13]

# %%
fib.index(13) #encontrando o índice de algum elemento da lista
# Out:
# 5

# %%
x = [3, 2, 1, "blast off!"] #listas acomodam qualquer tipo de variável e podem ser heterogêneas
y = x
y[1] = "TWO"
print(x)
# Out:
# [3, 'TWO', 1, 'blast off!']

# %% [markdown]
# # Conteiners - Tuples(tuplas)

# %%
a = 1, 2, 5, 3  # length-4 tuple
b = (42,)       # length-1 tuple, defined by comma
c = (42)        # not a tuple, just the number 42
d = ()          # length-0 tuple- no commas means no elements

# %%
(1, 2) + (3, 4) #Tuplas parecem com listas, mas são imutáveis
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# # Dicionários

# %%
# A dictionary on one line that stores info about Einstein
al = {"first": "Albert", "last": "Einstein", "birthday": [1879, 3, 14]}

# You can split up dicts onto many lines
constants = {
    'pi': 3.14159,
    "e": 2.718,
    "h": 6.62606957e-34,
    True: 1.0,
    }

# A dict being formed from a list of (key, value) tuples
axes = dict([(1, "x"), (2, "y"), (3, "z")])

# %%
constants['e']
# Out:
# 2.718

# %%
axes[3]
# Out:
# 'z'

# %%
al['birthday']
# Out:
# [1879, 3, 14]

# %%
constants[False] = 0.0
del axes[3]
al['first'] = "You can call me Al"

# %%
d = {}
d['d'] = d
d
# Out:
# {'d': {...}}

# %%
{}     # empty dict
set()  # empty set
# Out:
# set()

# %%
"N_A" in constants
# Out:
# False

# %%
axes.update({1: 'r', 2: 'phi', 3: 'theta'})
axes
# Out:
# {1: 'r', 2: 'phi', 3: 'theta'}
